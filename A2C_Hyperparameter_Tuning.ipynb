# %% [markdown]
# # **Library Loading**

# %%
# !pip install stable-baselines3[extra]
# !pip install shimmy>=2.0
# !pip install swig
# !pip install pyvirtualdisplay
# !pip install sbx-rl
# !pip install optuna
# !pip install "optuna>=3.3.0" "optuna-dashboard>=0.12.0"
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (1.1.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (4.11.0.86)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (0.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (11.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3[extra]) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (5.29.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 39.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 27.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.9 MB/s eta 0:00:00
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 13.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable-baselines3-2.6.0
# Collecting swig
#   Downloading swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.7 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.3.1
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0
# Collecting sbx-rl
#   Downloading sbx_rl-0.20.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: stable_baselines3<3.0,>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from sbx-rl) (2.6.0)
# Requirement already satisfied: jax>=0.4.24 in /usr/local/lib/python3.11/dist-packages (from sbx-rl) (0.5.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from sbx-rl) (0.5.1)
# Requirement already satisfied: flax in /usr/local/lib/python3.11/dist-packages (from sbx-rl) (0.10.6)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from sbx-rl) (0.2.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sbx-rl) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from sbx-rl) (13.9.4)
# Requirement already satisfied: tensorflow_probability in /usr/local/lib/python3.11/dist-packages (from sbx-rl) (0.25.0)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.24->sbx-rl) (0.4.1)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.24->sbx-rl) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.24->sbx-rl) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.24->sbx-rl) (1.15.2)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.5.0->sbx-rl) (1.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.5.0->sbx-rl) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.5.0->sbx-rl) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.5.0->sbx-rl) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.5.0->sbx-rl) (3.10.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax->sbx-rl) (1.1.0)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax->sbx-rl) (0.11.12)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax->sbx-rl) (0.1.74)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from flax->sbx-rl) (4.13.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax->sbx-rl) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax->sbx-rl) (0.1.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->sbx-rl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->sbx-rl) (2.19.1)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from optax->sbx-rl) (1.4.0)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->sbx-rl) (0.1.89)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax->sbx-rl) (1.12.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_probability->sbx-rl) (1.17.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from tensorflow_probability->sbx-rl) (4.4.2)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow_probability->sbx-rl) (0.6.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow_probability->sbx-rl) (0.1.9)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->sbx-rl) (0.12.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3<3.0,>=2.5.0->sbx-rl) (0.0.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->sbx-rl) (0.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (1.3.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow_probability->sbx-rl) (25.3.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow_probability->sbx-rl) (1.17.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.5.0->sbx-rl) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.5.0->sbx-rl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.5.0->sbx-rl) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.5.0->sbx-rl) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.5.0->sbx-rl) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.5.0->sbx-rl) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.5.0->sbx-rl) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.5.0->sbx-rl) (2.9.0.post0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->sbx-rl) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->sbx-rl) (5.29.4)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->sbx-rl) (4.12.2)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->sbx-rl) (3.20.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3<3.0,>=2.5.0->sbx-rl) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3<3.0,>=2.5.0->sbx-rl) (2025.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epy]->optax->sbx-rl) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epy]->optax->sbx-rl) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.5.0->sbx-rl) (3.0.2)
# Downloading sbx_rl-0.20.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: sbx-rl
# Successfully installed sbx-rl-0.20.0
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.1)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 7.6 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 16.4 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0
# Requirement already satisfied: optuna>=3.3.0 in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Collecting optuna-dashboard>=0.12.0
#   Downloading optuna_dashboard-0.18.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.3.0) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna>=3.3.0) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna>=3.3.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.3.0) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.3.0) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna>=3.3.0) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna>=3.3.0) (6.0.2)
# Collecting bottle>=0.13.0 (from optuna-dashboard>=0.12.0)
#   Downloading bottle-0.13.3-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from optuna-dashboard>=0.12.0) (1.6.1)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna>=3.3.0) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna>=3.3.0) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.3.0) (3.2.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-dashboard>=0.12.0) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-dashboard>=0.12.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-dashboard>=0.12.0) (3.6.0)
# Downloading optuna_dashboard-0.18.0-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 52.3 MB/s eta 0:00:00
# Downloading bottle-0.13.3-py2.py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.2/104.2 kB 8.5 MB/s eta 0:00:00
# Installing collected packages: bottle, optuna-dashboard
# Successfully installed bottle-0.13.3 optuna-dashboard-0.18.0

# %%
import gymnasium as gym
from gymnasium import spaces
import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
import numpy as np
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from math import radians
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3 import DQN
from stable_baselines3 import A2C
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.buffers import RolloutBuffer
import random as rand

import torch
import torch.nn as nn

from typing import Any, Dict

# %% [markdown]
# # **Video Loading**

# %%
#'eval_video/*.mp4'

def show_video(path):
    mp4list = glob.glob(path)
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

# %% [markdown]
# # **Clear Training Videos**

# %%
! rm -rf /content/video
! rm -rf /content/mountain_cart_tensorboard
! rm -rf /content/eval_video_dqn
! rm -rf /content/eval_video_ppo

# %% [markdown]
# # **Output Quantizing** [2]

# %%
def discretize_state_obs(obs, env):
  try:
    assert not np.any(np.isnan(obs)), "NaN in obs"
    assert not np.any(np.isinf(obs)), "inf in obs"
    upper_bounds = env.observation_space.high
    lower_bounds = env.observation_space.low
    state_buckets = (20, 20)

    scaling_factors = [(obs[i] + abs(lower_bounds[i])) / (upper_bounds[i] - lower_bounds[i]) for i in range(len(obs))]
    new_obs = [int(round((state_buckets[i] - 1) * scaling_factors[i])) for i in range(len(obs))]
    new_obs = [min(max(0, new_obs[i]), state_buckets[i] - 1) for i in range(len(obs))]
    return tuple(new_obs)
  except Exception as e:
    print('Error in discretize_state_obs: ', e)
    print("OBS: ", obs)
    raise e

# %%
def make_env(env_id, rank, seed=0):
    """
    Utility function for multiprocessed env.

    :param env_id: (str) the environment ID
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    """

    def _init():
        env = gym.make(env_id)
        env = gym.wrappers.TransformObservation(env, lambda obs: discretize_state_obs(obs, env), env.observation_space)
        # use a seed for reproducibility
        # Important: use a different seed for each environment
        # otherwise they would generate the same experiences
        env.reset(seed=seed + rank)
        return env

    set_random_seed(seed)
    return _init

# %% [markdown]
# # **Hyperparameter Tuning for A2C**

# %%
ENV = gym.make("MountainCar-v0")
ENV = gym.wrappers.TransformObservation(ENV, lambda obs: discretize_state_obs(obs, ENV), ENV.observation_space)

DEFAULT_HYPERPARAMS = {
    "policy": "MlpPolicy",
    "env": ENV,
    "normalize_advantage": True
}

N_TRIALS = 100
N_STARTUP_TRIALS = 5
N_EVALUATIONS = 5
N_TIMESTEPS = int(5e5)
EVAL_FREQ = int(N_TIMESTEPS / N_EVALUATIONS)
N_EVAL_EPISODES = 100

def sample_a2c_params(trial: optuna.Trial) -> Dict[str, Any]:
    gamma = 1.0 - trial.suggest_float("gamma", 0.0001, 0.1, log=True)
    max_grad_norm = trial.suggest_float("max_grad_norm", 0.3, 5.0, log=True)
    gae_lambda = 1.0 - trial.suggest_float("gae_lambda", 0.001, 0.2, log=True)
    n_steps_exp = trial.suggest_int("n_steps_exp", 8, 15, log=True)
    n_steps = 2**n_steps_exp
    learning_rate = trial.suggest_float("lr", 1e-7, 1e-3, log=True)
    vf_coef = trial.suggest_float("vf_coef", 0.01, 1, log=True)
    ent_coef = trial.suggest_float("ent_coef", 0.00001, 0.1, log=True)
    #ortho_init = trial.suggest_categorical("ortho_init", [True, False])
    #activation_fn = trial.suggest_categorical("activation_fn", ["tanh", "relu"])
    rms_prop_eps = trial.suggest_float("rms_prop_eps", 1e-8, 1e-3, log=True)
    use_rms_prop = trial.suggest_categorical("use_rms_prop", [True, False])

    """
    buffer_size = trial.suggest_int("buffer_size", 10000, 100000)
    rollout_buffer_type = trial.suggest_categorical("rollout_buffer_type", ["None", "RolloutBuffer"])

    if rollout_buffer_type == "RolloutBuffer":
        rollout_buffer_class = RolloutBuffer
        rollout_buffer_kwargs = {
            "buffer_size": buffer_size,
            "observation_space": ENV.observation_space,
            "action_space": ENV.action_space
        }

    else:
        rollout_buffer_class = None
        rollout_buffer_kwargs = None
    """

    return {
        "n_steps": n_steps,
        "gamma": gamma,
        "gae_lambda": gae_lambda,
        "learning_rate": learning_rate,
        "ent_coef": ent_coef,
        "vf_coef":vf_coef,
        "max_grad_norm": max_grad_norm,
        "rms_prop_eps": rms_prop_eps,
        "use_rms_prop": use_rms_prop,
        #"rollout_buffer_class": rollout_buffer_class,
        #"rollout_buffer_kwargs": rollout_buffer_kwargs,
    }

# %%
class TrialEvalCallback(EvalCallback):
    def __init__(
        self,
        eval_env: gym.Env,
        trial: optuna.Trial,
        n_eval_episodes: int = 100,
        eval_freq: int = 10000,
        deterministic: bool = True,
        verbose: int = 0,
    ):
        super().__init__(
            eval_env=eval_env,
            n_eval_episodes=n_eval_episodes,
            eval_freq=eval_freq,
            deterministic=deterministic,
            verbose=verbose,
        )
        self.trial = trial
        self.eval_idx = 0
        self.is_pruned = False

    def _on_step(self) -> bool:
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            super()._on_step()
            self.eval_idx += 1
            self.trial.report(self.last_mean_reward, self.eval_idx)
            # Prune trial if need.
            if self.trial.should_prune():
                self.is_pruned = True
                return False
        return True

# %%
def objective(trial: optuna.Trial) -> float:
    kwargs = DEFAULT_HYPERPARAMS.copy()
    kwargs.update(sample_a2c_params(trial))

    # Create the RL model.
    model = A2C(**kwargs)
    eval_env = gym.make("MountainCar-v0")
    eval_env = gym.wrappers.TransformObservation(eval_env, lambda obs: discretize_state_obs(obs, eval_env), eval_env.observation_space)
    eval_env = Monitor(eval_env)

    eval_callback = TrialEvalCallback(
        eval_env, trial, n_eval_episodes=N_EVAL_EPISODES, eval_freq=EVAL_FREQ, deterministic=True
    )

    nan_encountered = False
    try:
        model.learn(N_TIMESTEPS, callback=eval_callback)
    except AssertionError as e:
        # Sometimes, random hyperparams can generate NaN.
        print(e)
        nan_encountered = True
    finally:
        # Free memory.
        model.env.close()
        eval_env.close()

    # Tell the optimizer that the trial failed.
    if nan_encountered:
        return float("nan")

    if eval_callback.is_pruned:
        raise optuna.exceptions.TrialPruned()

    return eval_callback.last_mean_reward

# %%
if __name__ == '__main__':
  torch.set_num_threads(1)

  sampler = TPESampler(n_startup_trials=N_STARTUP_TRIALS)
  pruner = MedianPruner(n_startup_trials=N_STARTUP_TRIALS, n_warmup_steps=N_EVALUATIONS // 4)

  study = optuna.create_study(sampler=sampler, storage="sqlite:///db.sqlite3", pruner=pruner, direction="maximize")

  try:
    study.optimize(objective, n_trials=N_TRIALS, timeout=86400)
  except KeyboardInterrupt:
    pass
  print("Number of finished trails; ", len(study.trials))
  print("Best Trial:")
  trial = study.best_trial

  print("  Value: ", trial.value)
  print("  Params: ")
  for k, v in trial.params.items():
    print("    {}: {}".format(k,v))

  print("User Attributes:")
  for k,v in trial.user_attrs.items():
    print("  {}: {}".format(k,v))

  ENV.close()
# Out:
# [I 2025-04-27 15:54:43,273] A new study created in RDB with name: no-name-abb6a19e-13bd-4615-9b70-ac8e70fae7f0
# [I 2025-04-27 16:06:19,180] Trial 0 finished with value: -200.0 and parameters: {'gamma': 0.00012171855494882901, 'max_grad_norm': 0.4614504377134854, 'gae_lambda': 0.0025791430195552137, 'n_steps_exp': 14, 'lr': 2.850203830682807e-06, 'vf_coef': 0.04920649906995222, 'ent_coef': 1.4383752430327301e-05, 'rms_prop_eps': 5.69639110647575e-08, 'use_rms_prop': False}. Best is trial 0 with value: -200.0.
# [I 2025-04-27 16:19:11,380] Trial 1 finished with value: -200.0 and parameters: {'gamma': 0.011016226132404548, 'max_grad_norm': 0.4326054811521159, 'gae_lambda': 0.03514206002313687, 'n_steps_exp': 15, 'lr': 1.3758281436290249e-05, 'vf_coef': 0.5706115078921707, 'ent_coef': 0.003818619323483286, 'rms_prop_eps': 3.0577581425137026e-08, 'use_rms_prop': False}. Best is trial 0 with value: -200.0.
# [I 2025-04-27 16:31:49,182] Trial 2 finished with value: -200.0 and parameters: {'gamma': 0.0004876164488219553, 'max_grad_norm': 0.7026650542176989, 'gae_lambda': 0.003463174089478831, 'n_steps_exp': 10, 'lr': 0.0004826924759787351, 'vf_coef': 0.010996396219271365, 'ent_coef': 0.0001233630574477935, 'rms_prop_eps': 2.5398031709465145e-05, 'use_rms_prop': False}. Best is trial 0 with value: -200.0.
# [I 2025-04-27 16:44:29,162] Trial 3 finished with value: -200.0 and parameters: {'gamma': 0.0013715997188204578, 'max_grad_norm': 0.4058053056293553, 'gae_lambda': 0.006749715839815357, 'n_steps_exp': 11, 'lr': 0.00017430925191998727, 'vf_coef': 0.5098790180677966, 'ent_coef': 0.0007292388953020328, 'rms_prop_eps': 1.6542519950522913e-08, 'use_rms_prop': False}. Best is trial 0 with value: -200.0.
# [I 2025-04-27 16:57:18,781] Trial 4 finished with value: -177.6 and parameters: {'gamma': 0.001345109977483671, 'max_grad_norm': 0.866881944779409, 'gae_lambda': 0.0022041198645669766, 'n_steps_exp': 8, 'lr': 0.00014873761184142873, 'vf_coef': 0.08195608622843578, 'ent_coef': 0.080037004469273, 'rms_prop_eps': 6.003951202932881e-07, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 17:09:58,798] Trial 5 finished with value: -200.0 and parameters: {'gamma': 0.05428827595382834, 'max_grad_norm': 2.796806020613087, 'gae_lambda': 0.15901507685548763, 'n_steps_exp': 8, 'lr': 2.804561528711376e-07, 'vf_coef': 0.08992604488938025, 'ent_coef': 0.08445007007398937, 'rms_prop_eps': 0.0009376372647659251, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 17:22:34,620] Trial 6 finished with value: -200.0 and parameters: {'gamma': 0.0055306746614391, 'max_grad_norm': 1.4763779336364542, 'gae_lambda': 0.0010652444993412794, 'n_steps_exp': 8, 'lr': 4.4181848257804455e-05, 'vf_coef': 0.027747947094408244, 'ent_coef': 0.09485156037437507, 'rms_prop_eps': 1.6781568733734926e-06, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 17:34:55,359] Trial 7 finished with value: -200.0 and parameters: {'gamma': 0.0007894670277187138, 'max_grad_norm': 1.3985614143035847, 'gae_lambda': 0.020893152105997383, 'n_steps_exp': 10, 'lr': 0.0008433013846254671, 'vf_coef': 0.18939588927027076, 'ent_coef': 0.0065088741365337864, 'rms_prop_eps': 2.781115130596611e-06, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 17:46:53,033] Trial 8 finished with value: -200.0 and parameters: {'gamma': 0.00011893216897193843, 'max_grad_norm': 2.8336225045649, 'gae_lambda': 0.0010176395302285873, 'n_steps_exp': 12, 'lr': 2.102316626999743e-06, 'vf_coef': 0.20189267492609878, 'ent_coef': 0.009637787301878243, 'rms_prop_eps': 3.874409849866996e-07, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 17:59:28,149] Trial 9 finished with value: -200.0 and parameters: {'gamma': 0.0230517610658698, 'max_grad_norm': 4.9375543396233885, 'gae_lambda': 0.009430475383128934, 'n_steps_exp': 9, 'lr': 8.657030677564004e-05, 'vf_coef': 0.026793045737956916, 'ent_coef': 0.0003797165492468824, 'rms_prop_eps': 5.286139479364505e-05, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 18:11:39,819] Trial 10 finished with value: -200.0 and parameters: {'gamma': 0.003007331769242154, 'max_grad_norm': 0.8788493617144091, 'gae_lambda': 0.07377207995379761, 'n_steps_exp': 9, 'lr': 1.699593464475452e-05, 'vf_coef': 0.18303860751078108, 'ent_coef': 0.026863946785100734, 'rms_prop_eps': 3.229580512479266e-07, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 18:23:58,564] Trial 11 finished with value: -198.72 and parameters: {'gamma': 0.0001167016799872733, 'max_grad_norm': 0.3055593096357257, 'gae_lambda': 0.00298948793351625, 'n_steps_exp': 15, 'lr': 1.1796372441232595e-06, 'vf_coef': 0.058114942122011466, 'ent_coef': 1.0407151372964206e-05, 'rms_prop_eps': 8.161849540739616e-08, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 18:36:10,779] Trial 12 finished with value: -200.0 and parameters: {'gamma': 0.00032625471867744047, 'max_grad_norm': 0.3205709904673232, 'gae_lambda': 0.00275902798953973, 'n_steps_exp': 13, 'lr': 1.2260492805734882e-07, 'vf_coef': 0.07133144359563423, 'ent_coef': 1.4829274315920802e-05, 'rms_prop_eps': 1.9434589383616233e-07, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 18:48:16,185] Trial 13 finished with value: -200.0 and parameters: {'gamma': 0.0022462388249082127, 'max_grad_norm': 0.7634054170067737, 'gae_lambda': 0.005135372360807229, 'n_steps_exp': 12, 'lr': 9.629114111064478e-07, 'vf_coef': 0.03634569148050682, 'ent_coef': 0.00012039136230823077, 'rms_prop_eps': 1.4039953285766356e-05, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 19:00:50,558] Trial 14 finished with value: -200.0 and parameters: {'gamma': 0.00028798721791056683, 'max_grad_norm': 0.5765153963244604, 'gae_lambda': 0.0017953554236032152, 'n_steps_exp': 15, 'lr': 4.645727652005543e-06, 'vf_coef': 0.015728663484797813, 'ent_coef': 0.0018451311659149685, 'rms_prop_eps': 1.0919707870990686e-07, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 19:12:54,961] Trial 15 finished with value: -200.0 and parameters: {'gamma': 0.0011141636879866965, 'max_grad_norm': 1.0905046314409752, 'gae_lambda': 0.01684672730713354, 'n_steps_exp': 9, 'lr': 6.814415062568804e-07, 'vf_coef': 0.10538647941273681, 'ent_coef': 5.015108386216328e-05, 'rms_prop_eps': 6.530289429226507e-07, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 19:25:01,304] Trial 16 finished with value: -200.0 and parameters: {'gamma': 0.008073860746385629, 'max_grad_norm': 2.0033365199561426, 'gae_lambda': 0.005626575816502651, 'n_steps_exp': 13, 'lr': 4.257951532480487e-05, 'vf_coef': 0.9394323461098592, 'ent_coef': 0.00021866949010908773, 'rms_prop_eps': 1.109398918190765e-08, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 19:36:57,557] Trial 17 finished with value: -200.0 and parameters: {'gamma': 0.0002650990439958526, 'max_grad_norm': 0.30168705779267757, 'gae_lambda': 0.0014646901935897333, 'n_steps_exp': 11, 'lr': 6.537082643345773e-06, 'vf_coef': 0.12827386137582145, 'ent_coef': 0.031114200083068498, 'rms_prop_eps': 9.92697080007303e-07, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 19:48:47,489] Trial 18 finished with value: -200.0 and parameters: {'gamma': 0.0001028236769135863, 'max_grad_norm': 0.5809818472033326, 'gae_lambda': 0.010649088040013955, 'n_steps_exp': 10, 'lr': 0.00025746400393262094, 'vf_coef': 0.05333402435510831, 'ent_coef': 0.0013676649959327633, 'rms_prop_eps': 6.501842255507233e-06, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 20:00:50,560] Trial 19 finished with value: -200.0 and parameters: {'gamma': 0.021319088929208415, 'max_grad_norm': 0.9585370719206068, 'gae_lambda': 0.003940759849307503, 'n_steps_exp': 8, 'lr': 8.543079413618251e-07, 'vf_coef': 0.3185809004048731, 'ent_coef': 3.691848326518546e-05, 'rms_prop_eps': 0.00020784477410300725, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 20:12:49,467] Trial 20 finished with value: -200.0 and parameters: {'gamma': 0.0843731250148214, 'max_grad_norm': 1.8269205146040917, 'gae_lambda': 0.0021859221001790845, 'n_steps_exp': 12, 'lr': 2.5136425686281348e-05, 'vf_coef': 0.0631826777905866, 'ent_coef': 0.0259950180545696, 'rms_prop_eps': 8.588618296351813e-08, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 20:24:47,999] Trial 21 finished with value: -200.0 and parameters: {'gamma': 0.00016728562885491748, 'max_grad_norm': 0.43983803619957035, 'gae_lambda': 0.002386702994051341, 'n_steps_exp': 14, 'lr': 2.7317063970337494e-06, 'vf_coef': 0.044831424610637695, 'ent_coef': 1.0313481079743207e-05, 'rms_prop_eps': 6.08555073914089e-08, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 20:36:55,699] Trial 22 finished with value: -200.0 and parameters: {'gamma': 0.0005265971557300966, 'max_grad_norm': 0.5355561782701214, 'gae_lambda': 0.0016968512758250554, 'n_steps_exp': 13, 'lr': 3.711957472568952e-07, 'vf_coef': 0.022436244995305412, 'ent_coef': 2.75569923750111e-05, 'rms_prop_eps': 5.350302415201085e-08, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 20:49:02,948] Trial 23 finished with value: -200.0 and parameters: {'gamma': 0.00017241701963526652, 'max_grad_norm': 0.3655218292919749, 'gae_lambda': 0.00372026176638542, 'n_steps_exp': 14, 'lr': 1.3984800819871554e-06, 'vf_coef': 0.038901294135598945, 'ent_coef': 7.484597573512325e-05, 'rms_prop_eps': 1.6513412035498795e-07, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 21:01:09,134] Trial 24 finished with value: -200.0 and parameters: {'gamma': 0.0006102312028151203, 'max_grad_norm': 0.5388679253543405, 'gae_lambda': 0.007511937966155825, 'n_steps_exp': 14, 'lr': 6.268825795457831e-06, 'vf_coef': 0.08047589904249514, 'ent_coef': 2.2397638484423087e-05, 'rms_prop_eps': 2.981136369870655e-08, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 21:14:02,350] Trial 25 finished with value: -200.0 and parameters: {'gamma': 0.0016100081669409867, 'max_grad_norm': 0.651867592080614, 'gae_lambda': 0.031018865092322163, 'n_steps_exp': 15, 'lr': 3.001931089197237e-06, 'vf_coef': 0.13480285450990642, 'ent_coef': 0.0003704424236702516, 'rms_prop_eps': 7.065166938557482e-07, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 21:25:56,079] Trial 26 finished with value: -200.0 and parameters: {'gamma': 0.00019507847909063357, 'max_grad_norm': 0.43358313123621756, 'gae_lambda': 0.0029335213099278795, 'n_steps_exp': 14, 'lr': 2.55990956769492e-07, 'vf_coef': 0.01634417002064132, 'ent_coef': 1.0529274411416852e-05, 'rms_prop_eps': 2.2787477274654386e-07, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 21:37:52,583] Trial 27 finished with value: -200.0 and parameters: {'gamma': 0.0003592243233266209, 'max_grad_norm': 0.35775368676149444, 'gae_lambda': 0.0013810621267702954, 'n_steps_exp': 13, 'lr': 9.623431448094032e-06, 'vf_coef': 0.05730356832321122, 'ent_coef': 7.893909715780059e-05, 'rms_prop_eps': 2.8429133912611067e-06, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 21:50:55,114] Trial 28 finished with value: -200.0 and parameters: {'gamma': 0.000930494080342733, 'max_grad_norm': 0.8186099747309001, 'gae_lambda': 0.004872731675669121, 'n_steps_exp': 15, 'lr': 0.00011813492366143765, 'vf_coef': 0.03419026717444184, 'ent_coef': 2.0952871142924692e-05, 'rms_prop_eps': 2.2421603465701192e-08, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 22:03:24,648] Trial 29 finished with value: -200.0 and parameters: {'gamma': 0.004391374233495778, 'max_grad_norm': 1.0314758894143956, 'gae_lambda': 0.010379841446054501, 'n_steps_exp': 12, 'lr': 1.3366718448272251e-05, 'vf_coef': 0.3262236202444998, 'ent_coef': 0.0028184422281164623, 'rms_prop_eps': 4.055795395816403e-08, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 22:16:11,092] Trial 30 finished with value: -200.0 and parameters: {'gamma': 0.01299513248734163, 'max_grad_norm': 0.48093517945042497, 'gae_lambda': 0.060288475379480434, 'n_steps_exp': 15, 'lr': 5.106118362722749e-07, 'vf_coef': 0.1172098265201898, 'ent_coef': 0.010545235668877334, 'rms_prop_eps': 1.0881597108780547e-07, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 22:28:50,631] Trial 31 finished with value: -200.0 and parameters: {'gamma': 0.013196090791750072, 'max_grad_norm': 0.6449366548822346, 'gae_lambda': 0.033149964177115535, 'n_steps_exp': 14, 'lr': 0.000479281357302485, 'vf_coef': 0.8176006866634913, 'ent_coef': 0.0036409977387831115, 'rms_prop_eps': 1.0605733621840426e-08, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 22:41:21,921] Trial 32 finished with value: -200.0 and parameters: {'gamma': 0.007840906975671707, 'max_grad_norm': 0.37557545695039024, 'gae_lambda': 0.05837106694925169, 'n_steps_exp': 10, 'lr': 1.5776778669894163e-06, 'vf_coef': 0.4989651080161165, 'ent_coef': 0.0005696914770631043, 'rms_prop_eps': 2.5566643514923156e-08, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 22:54:22,302] Trial 33 finished with value: -200.0 and parameters: {'gamma': 0.02939937741706945, 'max_grad_norm': 0.4720364729382235, 'gae_lambda': 0.1177819135310341, 'n_steps_exp': 15, 'lr': 4.22699238467722e-06, 'vf_coef': 0.08721593952435293, 'ent_coef': 0.05116692725033333, 'rms_prop_eps': 5.729567102223236e-08, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 23:06:46,743] Trial 34 finished with value: -200.0 and parameters: {'gamma': 0.0017458471628251772, 'max_grad_norm': 0.3129941083212435, 'gae_lambda': 0.028787747053012007, 'n_steps_exp': 11, 'lr': 5.128055363470744e-05, 'vf_coef': 0.04991454400409597, 'ent_coef': 0.00018635028255254525, 'rms_prop_eps': 4.010454755569945e-07, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 23:19:07,357] Trial 35 finished with value: -200.0 and parameters: {'gamma': 0.0037578749633417866, 'max_grad_norm': 0.40551879988325196, 'gae_lambda': 0.041809006628655165, 'n_steps_exp': 14, 'lr': 2.0626103885914037e-05, 'vf_coef': 0.15971375202510923, 'ent_coef': 0.015916550253977656, 'rms_prop_eps': 1.4138474748974771e-06, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 23:31:37,501] Trial 36 finished with value: -200.0 and parameters: {'gamma': 0.0001325844265292129, 'max_grad_norm': 0.7105778366303777, 'gae_lambda': 0.01594742670401474, 'n_steps_exp': 13, 'lr': 0.00020583923678963782, 'vf_coef': 0.010267235737990262, 'ent_coef': 0.0007635510179663099, 'rms_prop_eps': 1.3977871026446037e-07, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 23:44:13,698] Trial 37 finished with value: -200.0 and parameters: {'gamma': 0.05140526601807952, 'max_grad_norm': 1.251819070642583, 'gae_lambda': 0.0033539303845274765, 'n_steps_exp': 8, 'lr': 0.0006245688873797086, 'vf_coef': 0.0705084570481546, 'ent_coef': 0.06111370838839377, 'rms_prop_eps': 4.4115322150204774e-07, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-27 23:56:49,472] Trial 38 finished with value: -200.0 and parameters: {'gamma': 0.006889960116708614, 'max_grad_norm': 0.3682150551730741, 'gae_lambda': 0.007139575381940312, 'n_steps_exp': 15, 'lr': 1.5189926338578837e-06, 'vf_coef': 0.2335529959652214, 'ent_coef': 0.005996945764094996, 'rms_prop_eps': 1.5988930672796218e-08, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 00:09:03,094] Trial 39 finished with value: -200.0 and parameters: {'gamma': 0.0007273712345130429, 'max_grad_norm': 3.9259742379950513, 'gae_lambda': 0.0011293199410155764, 'n_steps_exp': 9, 'lr': 7.072287147757318e-05, 'vf_coef': 0.021008494060262325, 'ent_coef': 5.027047347546828e-05, 'rms_prop_eps': 3.610049497017174e-08, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 00:21:08,506] Trial 40 finished with value: -180.95 and parameters: {'gamma': 0.00038990024368461317, 'max_grad_norm': 0.4797527399517765, 'gae_lambda': 0.0021240448065558237, 'n_steps_exp': 14, 'lr': 1.282006788664944e-07, 'vf_coef': 0.09294254259591227, 'ent_coef': 0.005388188421209361, 'rms_prop_eps': 7.294305582986347e-06, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 00:33:21,667] Trial 41 finished with value: -200.0 and parameters: {'gamma': 0.0002258244057805346, 'max_grad_norm': 0.4904904915355955, 'gae_lambda': 0.0019409189825253719, 'n_steps_exp': 14, 'lr': 2.2581636832600871e-07, 'vf_coef': 0.09347449835201799, 'ent_coef': 0.005193084471730666, 'rms_prop_eps': 7.02613196796745e-06, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 00:46:02,786] Trial 42 finished with value: -200.0 and parameters: {'gamma': 0.00041593688562358347, 'max_grad_norm': 0.40700594527946904, 'gae_lambda': 0.0024281734055671598, 'n_steps_exp': 15, 'lr': 1.5538480603687618e-07, 'vf_coef': 0.0671036628070269, 'ent_coef': 0.002493637880692878, 'rms_prop_eps': 2.9120647746814878e-05, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 00:58:28,217] Trial 43 finished with value: -200.0 and parameters: {'gamma': 0.00013851649276420388, 'max_grad_norm': 0.3361649982257964, 'gae_lambda': 0.001247764014687088, 'n_steps_exp': 13, 'lr': 9.764215945757903e-06, 'vf_coef': 0.265216572495625, 'ent_coef': 0.010641736470063617, 'rms_prop_eps': 7.356835694396227e-06, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 01:11:01,586] Trial 44 finished with value: -200.0 and parameters: {'gamma': 0.00010559548040937772, 'max_grad_norm': 0.6721989885742866, 'gae_lambda': 0.004134251034527758, 'n_steps_exp': 14, 'lr': 2.8697056832662105e-05, 'vf_coef': 0.028932823278599893, 'ent_coef': 0.017120600894875965, 'rms_prop_eps': 9.857873609761974e-05, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 01:23:26,252] Trial 45 finished with value: -200.0 and parameters: {'gamma': 0.0023392084268299826, 'max_grad_norm': 1.6886168507306836, 'gae_lambda': 0.02255227281087022, 'n_steps_exp': 12, 'lr': 4.873994298940024e-07, 'vf_coef': 0.15444523082391406, 'ent_coef': 0.001447728803808683, 'rms_prop_eps': 1.918771115726991e-06, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 01:36:29,106] Trial 46 finished with value: -200.0 and parameters: {'gamma': 0.0002708834921953883, 'max_grad_norm': 0.6026851671735867, 'gae_lambda': 0.002844943584633254, 'n_steps_exp': 15, 'lr': 1.4702065029721524e-07, 'vf_coef': 0.04426145528573866, 'ent_coef': 0.004266460755725477, 'rms_prop_eps': 1.4980736664414208e-05, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 01:49:09,726] Trial 47 finished with value: -200.0 and parameters: {'gamma': 0.0012158885505055847, 'max_grad_norm': 0.5302676006032981, 'gae_lambda': 0.0015893984545462471, 'n_steps_exp': 13, 'lr': 1.0307203067722066e-06, 'vf_coef': 0.11004746388275971, 'ent_coef': 1.6255653091011057e-05, 'rms_prop_eps': 2.578023220256343e-07, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 02:01:38,667] Trial 48 finished with value: -200.0 and parameters: {'gamma': 0.00046519713782465803, 'max_grad_norm': 0.7870922588612557, 'gae_lambda': 0.15285908970985146, 'n_steps_exp': 12, 'lr': 3.351657214631965e-06, 'vf_coef': 0.4511929794633518, 'ent_coef': 0.0009546644335582901, 'rms_prop_eps': 1.7150252483354857e-08, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 02:14:05,438] Trial 49 finished with value: -200.0 and parameters: {'gamma': 0.00021917147379510178, 'max_grad_norm': 0.4120140909162359, 'gae_lambda': 0.005715267714376335, 'n_steps_exp': 14, 'lr': 6.306251959413956e-06, 'vf_coef': 0.03268085594254664, 'ent_coef': 0.03959020872885846, 'rms_prop_eps': 4.2189143086828434e-06, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 02:26:01,488] Trial 50 finished with value: -200.0 and parameters: {'gamma': 0.0008514717687165417, 'max_grad_norm': 0.9143440384030613, 'gae_lambda': 0.0020320047780063967, 'n_steps_exp': 10, 'lr': 0.00010303444793380817, 'vf_coef': 0.7366489191128308, 'ent_coef': 0.017981604910014538, 'rms_prop_eps': 7.961782035667193e-08, 'use_rms_prop': True}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 02:37:36,299] Trial 51 finished with value: -200.0 and parameters: {'gamma': 0.0003686585753482394, 'max_grad_norm': 1.1408732236766757, 'gae_lambda': 0.0029878401427006758, 'n_steps_exp': 8, 'lr': 0.00040536878174193683, 'vf_coef': 0.012266728698792423, 'ent_coef': 0.0969414529494785, 'rms_prop_eps': 4.303266994985246e-05, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 02:49:04,334] Trial 52 finished with value: -200.0 and parameters: {'gamma': 0.0006103212753623461, 'max_grad_norm': 0.734296690277608, 'gae_lambda': 0.0010258583436148626, 'n_steps_exp': 9, 'lr': 0.0007946382814488047, 'vf_coef': 0.08182565449353488, 'ent_coef': 0.00013747370930110235, 'rms_prop_eps': 1.4698351157630378e-05, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 03:00:16,745] Trial 53 finished with value: -200.0 and parameters: {'gamma': 0.00015104112637982805, 'max_grad_norm': 0.8489863484459853, 'gae_lambda': 0.00464780299314129, 'n_steps_exp': 11, 'lr': 0.00029202133543271475, 'vf_coef': 0.022925473245247466, 'ent_coef': 0.0004073666941713419, 'rms_prop_eps': 0.00044848219112378547, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 03:12:07,696] Trial 54 finished with value: -200.0 and parameters: {'gamma': 0.002453619878247102, 'max_grad_norm': 0.30218515552677283, 'gae_lambda': 0.012270307450767327, 'n_steps_exp': 15, 'lr': 0.0001481914358785816, 'vf_coef': 0.09826844433353649, 'ent_coef': 4.641498789949119e-05, 'rms_prop_eps': 7.82289482742276e-05, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 03:23:30,494] Trial 55 finished with value: -200.0 and parameters: {'gamma': 0.00010103527802341497, 'max_grad_norm': 0.5961672589560171, 'gae_lambda': 0.0024537874886098234, 'n_steps_exp': 9, 'lr': 1.8545085038019734e-06, 'vf_coef': 0.05951675078679795, 'ent_coef': 3.323619904234289e-05, 'rms_prop_eps': 4.793109609531833e-06, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.
# [I 2025-04-28 03:34:42,599] Trial 56 finished with value: -200.0 and parameters: {'gamma': 0.00027314645463887753, 'max_grad_norm': 0.4633401811610334, 'gae_lambda': 0.0035219479152001866, 'n_steps_exp': 10, 'lr': 0.0009222912980860815, 'vf_coef': 0.19276033954315083, 'ent_coef': 1.2684461454696883e-05, 'rms_prop_eps': 1.9921977417009767e-05, 'use_rms_prop': False}. Best is trial 4 with value: -177.6.

# %%
! optuna-dashboard sqlite:///db.sqlite3 --artifact-dir ./artifact
